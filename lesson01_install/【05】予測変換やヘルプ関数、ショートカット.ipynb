# %% [markdown]
# <a href="https://colab.research.google.com/github/chemoinformatics-lecture/lecture-beginner/blob/main/lesson01_install/%E3%80%9005%E3%80%91%E4%BA%88%E6%B8%AC%E5%A4%89%E6%8F%9B%E3%82%84%E3%83%98%E3%83%AB%E3%83%97%E9%96%A2%E6%95%B0%E3%80%81%E3%82%B7%E3%83%A7%E3%83%BC%E3%83%88%E3%82%AB%E3%83%83%E3%83%88.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 新しいライブラリーをインストール

# %% [markdown]
# pubchemという化合物のデータベースにpythonからアクセスするためのライブラリー

# %%
# !pip install pubchempy
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %% [markdown]
# # ヘルプ関数を使用してみる。

# %% [markdown]
# どんなプログラムかを確認できる。

# %%
import pubchempy as pcp

# %%
help(pcp)
# Out:
# Help on module pubchempy:
#
# NAME
#     pubchempy - PubChemPy
#
# DESCRIPTION
#     Python interface for the PubChem PUG REST service.
#     https://github.com/mcs07/PubChemPy
#
# CLASSES
#     builtins.Exception(builtins.BaseException)
#         PubChemPyError
#             PubChemHTTPError
#                 BadRequestError
#                 MethodNotAllowedError
#                 NotFoundError
#                 ServerError
#                 TimeoutError
#                 UnimplementedError
#             ResponseParseError
#     builtins.Warning(builtins.Exception)
#         PubChemPyDeprecationWarning
#     builtins.object
#         Assay
#         Atom
#         Bond
#         BondType
#         Compound
#         CompoundIdType
#         CoordinateType
#         ProjectCategory
#         Substance
#
#     class Assay(builtins.object)
#      |  Assay(record)
#      |
#      |  Methods defined here:
#      |
#      |  __eq__(self, other)
#      |      Return self==value.
#      |
# ...

# %% [markdown]
# # 予測変換を使用してみる。

# %%
help(pcp.get_compounds)
# Out:
# Help on function get_compounds in module pubchempy:
#
# get_compounds(identifier, namespace='cid', searchtype=None, as_dataframe=False, **kwargs)
#     Retrieve the specified compound records from PubChem.
#
#     :param identifier: The compound identifier to use as a search query.
#     :param namespace: (optional) The identifier type, one of cid, name, smiles, sdf, inchi, inchikey or formula.
#     :param searchtype: (optional) The advanced search type, one of substructure, superstructure or similarity.
#     :param as_dataframe: (optional) Automatically extract the :class:`~pubchempy.Compound` properties into a pandas
#                          :class:`~pandas.DataFrame` and return that.
