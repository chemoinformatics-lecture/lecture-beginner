# %% [markdown]
# ファイルのダウンロード先
#
# https://figshare.com/articles/dataset/data_qm9_pkl_tar_gz/4293959/2
#
# data_qm9.pkl
#
# CSVファイルのダウンロード
# QM9_CSV_URL = "https://deepchemdata.s3-us-west-1.amazonaws.com/datasets/qm9.csv"
#
# kaggleのコンペで使われて整形されたもの
#
# https://www.kaggle.com/code/zaharch/quantum-machine-9-qm9/notebook
#
# data.covs.pickle(1.68 GB)

# %%
import numpy
import pandas as pd
import pickle

# %%
# macだと読み込めない？

with open("data_qm9.pkl", 'rb', ) as f:
    print(type(f))
    data_loaded = pickle.load(f, encoding='utf-8')
# Out:
# <class '_io.BufferedReader'>
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# Input In [15], in <cell line: 1>()
#       1 with open("data_qm9.pkl", 'rb', ) as f:
#       2     print(type(f))
# ----> 3     data_loaded = pickle.load(f, errors='strict', encoding='utf-8')
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0x92 in position 0: invalid start byte

# %%
help(pickle.load)
# Out:
# Help on built-in function load in module _pickle:
#
# load(file, *, fix_imports=True, encoding='ASCII', errors='strict', buffers=())
#     Read and return an object from the pickle data stored in a file.
#
#     This is equivalent to ``Unpickler(file).load()``, but may be more
#     efficient.
#
#     The protocol version of the pickle is detected automatically, so no
#     protocol argument is needed.  Bytes past the pickled object's
#     representation are ignored.
#
#     The argument *file* must have two methods, a read() method that takes
#     an integer argument, and a readline() method that requires no
#     arguments.  Both methods should return bytes.  Thus *file* can be a
#     binary file object opened for reading, an io.BytesIO object, or any
#     other custom object that meets this interface.
#
#     Optional keyword arguments are *fix_imports*, *encoding* and *errors*,
#     which are used to control compatibility support for pickle stream
# ...

# %%
df = pd.read_csv("qm9.csv")
df
# Out:
#             mol_id               smiles          A           B           C  \
# 0            gdb_1                    C  157.71180  157.709970  157.706990
# 1            gdb_2                    N  293.60975  293.541110  191.393970
# 2            gdb_3                    O  799.58812  437.903860  282.945450
# 3            gdb_4                  C#C    0.00000   35.610036   35.610036
# 4            gdb_5                  C#N    0.00000   44.593883   44.593883
# ...            ...                  ...        ...         ...         ...
# 133880  gdb_133881  C1C2C3C4C5OC14C5N23    3.59483    2.198990    1.904230
# 133881  gdb_133882  C1N2C3C2C2C4OC12C34    3.65648    2.142370    1.904390
# 133882  gdb_133883  C1N2C3C4C5C2C13CN45    3.67118    2.143140    1.895010
# 133883  gdb_133884  C1N2C3C4C5CC13C2C45    3.52845    2.151310    1.865820
# 133884  gdb_133885  C1N2C3C4C5OC13C2C45    3.64015    2.217640    1.937930
#
# ...

# %%
df.describe()
# Out:
#                    A              B              C             mu  \
# count  133885.000000  133885.000000  133885.000000  133885.000000
# mean        9.814382       1.406097       1.124921       2.706037
# std      1809.465666       1.583795       1.095618       1.530394
# min         0.000000       0.337120       0.331180       0.000000
# 25%         2.554430       1.091630       0.910480       1.588700
# 50%         3.090360       1.369940       1.078560       2.500000
# 75%         3.835820       1.653980       1.279540       3.636100
# max    619867.683140     437.903860     282.945450      29.556400
#
#                alpha           homo           lumo            gap  \
# count  133885.000000  133885.000000  133885.000000  133885.000000
# mean       75.191296      -0.239977       0.011124       0.251100
# std         8.187793       0.022131       0.046936       0.047519
# min         6.310000      -0.428600      -0.175000       0.024600
# ...

# %% [markdown]
# # kaggleのコンペで使われて整形されたもの

# %%
df  = pd.read_pickle('data.covs.pickle')

# %%
df.describe()
# Out:
#                  id  atom_index_0  atom_index_1  scalar_coupling_constant  \
# count  7.163689e+06  7.163689e+06  7.163689e+06              4.658147e+06
# mean   3.581844e+06  1.335605e+01  5.881862e+00              1.592165e+01
# std    2.067979e+06  3.269286e+00  4.993373e+00              3.494198e+01
# min    0.000000e+00  0.000000e+00  0.000000e+00             -3.621860e+01
# 25%    1.790922e+06  1.100000e+01  2.000000e+00             -2.549780e-01
# 50%    3.581844e+06  1.300000e+01  5.000000e+00              2.281130e+00
# 75%    5.372766e+06  1.600000e+01  8.000000e+00              7.390655e+00
# max    7.163688e+06  2.800000e+01  2.800000e+01              2.048800e+02
#
#                rc_A          rc_B          rc_C            mu         alpha  \
# count  7.163689e+06  7.163689e+06  7.163689e+06  7.163689e+06  7.163689e+06
# mean   4.009683e+00  1.382881e+00  1.124557e+00  2.464900e+00  7.738200e+01
# ...

# %%
df.columns
# Out:
# Index(['id', 'molecule_name', 'atom_index_0', 'atom_index_1', 'type',
#        'scalar_coupling_constant', 'rc_A', 'rc_B', 'rc_C', 'mu', 'alpha',
#        'homo', 'lumo', 'gap', 'r2', 'zpve', 'U0', 'U', 'H', 'G', 'Cv',
#        'freqs_min', 'freqs_max', 'freqs_mean', 'linear', 'mulliken_min',
#        'mulliken_max', 'mulliken_mean', 'mulliken_atom_0', 'mulliken_atom_1'],
#       dtype='object')

# %%
df.head()
# Out:
#         id     molecule_name  atom_index_0  atom_index_1  type  \
# 0  5174511  dsgdb9nsd_033805            11             7  2JHC
# 1  5174510  dsgdb9nsd_033805            11             6  3JHC
# 2  5174509  dsgdb9nsd_033805            11             5  2JHC
# 3  5174508  dsgdb9nsd_033805            11             4  1JHC
# 4  5174507  dsgdb9nsd_033805            11             3  2JHC
#
#    scalar_coupling_constant     rc_A     rc_B     rc_C      mu  ...      Cv  \
# 0                       NaN  3.54257  1.50643  1.34544  4.4029  ...  27.528
# 1                       NaN  3.54257  1.50643  1.34544  4.4029  ...  27.528
# 2                       NaN  3.54257  1.50643  1.34544  4.4029  ...  27.528
# 3                       NaN  3.54257  1.50643  1.34544  4.4029  ...  27.528
# 4                       NaN  3.54257  1.50643  1.34544  4.4029  ...  27.528
#
#    freqs_min  freqs_max   freqs_mean  linear  mulliken_min  mulliken_max  \
# ...

# %%
df2 = df[['molecule_name', 'homo', 'lumo']]
df2
# Out:
#             molecule_name    homo    lumo
# 0        dsgdb9nsd_033805 -0.2457 -0.0269
# 1        dsgdb9nsd_033805 -0.2457 -0.0269
# 2        dsgdb9nsd_033805 -0.2457 -0.0269
# 3        dsgdb9nsd_033805 -0.2457 -0.0269
# 4        dsgdb9nsd_033805 -0.2457 -0.0269
# ...                   ...     ...     ...
# 7163684  dsgdb9nsd_050526 -0.2354  0.0269
# 7163685  dsgdb9nsd_050526 -0.2354  0.0269
# 7163686  dsgdb9nsd_050526 -0.2354  0.0269
# 7163687  dsgdb9nsd_050526 -0.2354  0.0269
# 7163688  dsgdb9nsd_050526 -0.2354  0.0269
#
# [7163689 rows x 3 columns]

# %%
df2.plot(x='homo', y='lumo')
# Out:
# <AxesSubplot:xlabel='homo'>

# %%
pd.set_option('display.max_columns', 30)

# %%
df.head(3)
# Out:
#         id     molecule_name  atom_index_0  atom_index_1  type  \
# 0  5174511  dsgdb9nsd_033805            11             7  2JHC
# 1  5174510  dsgdb9nsd_033805            11             6  3JHC
# 2  5174509  dsgdb9nsd_033805            11             5  2JHC
#
#    scalar_coupling_constant     rc_A     rc_B     rc_C      mu  alpha    homo  \
# 0                       NaN  3.54257  1.50643  1.34544  4.4029   76.7 -0.2457
# 1                       NaN  3.54257  1.50643  1.34544  4.4029   76.7 -0.2457
# 2                       NaN  3.54257  1.50643  1.34544  4.4029   76.7 -0.2457
#
#      lumo     gap        r2      zpve          U0           U           H  \
# 0 -0.0269  0.2188  964.8507  0.126725 -363.615135 -363.608497 -363.607553
# 1 -0.0269  0.2188  964.8507  0.126725 -363.615135 -363.608497 -363.607553
# 2 -0.0269  0.2188  964.8507  0.126725 -363.615135 -363.608497 -363.607553
#
#             G      Cv  freqs_min  freqs_max   freqs_mean  linear  \
# ...
