# %% [markdown]
# # ファイルの確認

# %%
ls
# Out:
# README.md
# mopacの実行.ipynb
# mopacの計算ファイルの確認.ipynb
# openbabel及びpybelの使い方.ipynb
# phenol.arc
# phenol.dat
# phenol.out
# read_file.py

# %% [markdown]
# # outファイルの読み取り

# %%
with open('phenol.out', mode='r') as f:
    lines = f.readlines()
    for line in lines:
        print(line, end='')
# Out:
#  *******************************************************************************
#  **                                                                           **
#  **                              MOPAC v22.0.4                                **
#  **                                                                           **
#  *******************************************************************************
#  **          Digital Object Identifier (DOI): 10.5281/zenodo.6511958          **
#  **    Visit the DOI location for information on how to cite this program.    **
#  *******************************************************************************
#
#                               PM7 CALCULATION RESULTS
#
#  *******************************************************************************
#  *  CALCULATION DONE:                                Sat Sep 17 21:36:16 2022  *
#  *  PM7        - The PM7 Hamiltonian to be used
#  *  EF         - USE EF ROUTINE FOR MINIMUM SEARCH
#  *  T=         - A TIME OF 172800.0 SECONDS REQUESTED
#  *  DUMP=N     - RESTART FILE WRITTEN EVERY 7200.0 SECONDS REQUESTED
#  *******************************************************************************
# PM7 EF
#  c1ccc(cc1)O
#  InChI=1S/C6H6O/c7-6-4-2-1-3-5-6/h1-5,7H
#    ATOM   CHEMICAL          X               Y               Z
#   NUMBER   SYMBOL      (ANGSTROMS)     (ANGSTROMS)     (ANGSTROMS)
#
#      1       C         -1.87568000  *   0.03410000  *  -0.00509000  *
#      2       C         -1.19721000  *  -1.18589000  *  -0.00406000  *
#      3       C          0.19853000  *  -1.21088000  *   0.00191000  *
#      4       C          0.90327000  *  -0.01035000  *   0.00679000  *
#      5       C          0.23498000  *   1.20891000  *   0.00620000  *
#      6       C         -1.15951000  *   1.23167000  *   0.00014000  *
#      7       O          2.26679000  *   0.01257000  *   0.01209000  *
#      8       H         -2.96253000  *   0.05194000  *  -0.00994000  *
#      9       H         -1.75770000  *  -2.11714000  *  -0.00797000  *
#     10       H          0.71278000  *  -2.16634000  *   0.00273000  *
#     11       H          0.79829000  *   2.13748000  *   0.01024000  *
#     12       H         -1.68618000  *   2.18214000  *  -0.00059000  *
#     13       H          2.58978000  *  -0.90307000  *   0.00846000  *
#
#
#
#           CARTESIAN COORDINATES
#
#     NO.       ATOM           X           Y           Z
#
#      1         C         -1.8757      0.0341     -0.0051
#      2         C         -1.1972     -1.1859     -0.0041
#      3         C          0.1985     -1.2109      0.0019
#      4         C          0.9033     -0.0103      0.0068
#      5         C          0.2350      1.2089      0.0062
#      6         C         -1.1595      1.2317      0.0001
#      7         O          2.2668      0.0126      0.0121
#      8         H         -2.9625      0.0519     -0.0099
#      9         H         -1.7577     -2.1171     -0.0080
#     10         H          0.7128     -2.1663      0.0027
#     11         H          0.7983      2.1375      0.0102
#     12         H         -1.6862      2.1821     -0.0006
#     13         H          2.5898     -0.9031      0.0085
#
#  General Reference for PM7:
#  "Optimization of Parameters for Semiempirical Methods VI: More Modifications to the
#  NDDO Approximations and Re-optimization of Parameters", J. J. P. Stewart, J. Mol. Mod., 1:32, 19 (2013)
#  https://link.springer.com/article/10.1007/s00894-012-1667-x
#
#            Empirical Formula: C6 H6 O  =    13 atoms
#
#
#
#       MOLECULAR POINT GROUP   :   Cs
#
#
#       RHF CALCULATION, NO. OF DOUBLY OCCUPIED LEVELS = 18
#
#
#           Geometry optimization using EF
#
#           DIAGONAL MATRIX USED AS START HESSIAN
#
#  CYCLE:     1 TIME:   0.008 TIME LEFT:  2.00D  GRAD.:    32.029 HEAT: -21.37425
#  CYCLE:     2 TIME:   0.008 TIME LEFT:  2.00D  GRAD.:    22.806 HEAT: -21.69831
#  CYCLE:     3 TIME:   0.008 TIME LEFT:  2.00D  GRAD.:    18.505 HEAT: -21.85276
#  CYCLE:     4 TIME:   0.008 TIME LEFT:  2.00D  GRAD.:    17.332 HEAT: -21.95934
#  CYCLE:     5 TIME:   0.008 TIME LEFT:  2.00D  GRAD.:    16.448 HEAT: -21.98401
#  CYCLE:     6 TIME:   0.000 TIME LEFT:  2.00D  GRAD.:     9.455 HEAT: -22.04355
#  CYCLE:     7 TIME:   0.008 TIME LEFT:  2.00D  GRAD.:    12.308 HEAT: -22.05827
#  CYCLE:     8 TIME:   0.000 TIME LEFT:  2.00D  GRAD.:     6.726 HEAT: -22.09525
#  CYCLE:     9 TIME:   0.008 TIME LEFT:  2.00D  GRAD.:     9.561 HEAT: -22.10623
#  CYCLE:    10 TIME:   0.008 TIME LEFT:  2.00D  GRAD.:     6.164 HEAT: -22.12974
#  CYCLE:    11 TIME:   0.008 TIME LEFT:  2.00D  GRAD.:     5.949 HEAT: -22.13585
#  CYCLE:    12 TIME:   0.000 TIME LEFT:  2.00D  GRAD.:     3.141 HEAT: -22.14775
#  CYCLE:    13 TIME:   0.008 TIME LEFT:  2.00D  GRAD.:     2.610 HEAT: -22.15327
#  CYCLE:    14 TIME:   0.000 TIME LEFT:  2.00D  GRAD.:     1.115 HEAT: -22.15657
#  CYCLE:    15 TIME:   0.008 TIME LEFT:  2.00D  GRAD.:     0.997 HEAT: -22.15781
#
#      GRADIENT =  0.99656 IS LESS THAN CUTOFF =  1.00000
#
#
#
#  -------------------------------------------------------------------------------
#  PM7 EF
#  c1ccc(cc1)O
#  InChI=1S/C6H6O/c7-6-4-2-1-3-5-6/h1-5,7H
#
#
#      GEOMETRY OPTIMISED USING EIGENVECTOR FOLLOWING (EF).
#      SCF FIELD WAS ACHIEVED
#
#
#                               PM7 CALCULATION
#                                                        MOPAC v22.0.4 MacOS
#                                                        Sat Sep 17 21:36:16 2022
#
#
#
#
#           FINAL HEAT OF FORMATION =        -22.15781 KCAL/MOL =     -92.70830 KJ/MOL
#
#
#           COSMO AREA              =        129.57 SQUARE ANGSTROMS
#           COSMO VOLUME            =        119.27 CUBIC ANGSTROMS
#
#           GRADIENT NORM           =          0.99656          =       0.27640 PER ATOM
#           IONIZATION POTENTIAL    =          9.235653 EV
#           HOMO LUMO ENERGIES (EV) =         -9.236  0.035
#           NO. OF FILLED LEVELS    =         18
#           MOLECULAR WEIGHT        =         94.1128         POINT GROUP:  Cs
#
#           MOLECULAR DIMENSIONS (Angstroms)
#
#             Atom       Atom       Distance
#             H    13    H     8     5.68878
#             H    11    H     9     4.61502
#             C     1    H    10     0.00066
#
#
#           SCF CALCULATIONS        =         19
#
#           WALL-CLOCK TIME         =      0.102 SECONDS
#           COMPUTATION TIME        =      0.639 SECONDS
#
#
#
#
#    ATOM   CHEMICAL          X               Y               Z
#   NUMBER   SYMBOL      (ANGSTROMS)     (ANGSTROMS)     (ANGSTROMS)
#
#      1       C         -1.86955374  *   0.03491335  *  -0.00506995  *
#      2       C         -1.20247783  *  -1.18815219  *  -0.00388722  *
#      3       C          0.19065245  *  -1.23365596  *   0.00129355  *
#      4       C          0.88746807  *  -0.02450617  *   0.00658228  *
#      5       C          0.24174035  *   1.21695100  *   0.00579228  *
#      6       C         -1.14747898  *   1.23155235  *   0.00051874  *
#      7       O          2.24539294  *   0.03188680  *   0.01182574  *
#      8       H         -2.95600836  *   0.06214159  *  -0.00937433  *
#      9       H         -1.77214996  *  -2.11663407  *  -0.00805167  *
#     10       H          0.71628124  *  -2.18164772  *   0.00212199  *
#     11       H          0.82785442  *   2.13135928  *   0.01004968  *
#     12       H         -1.67901440  *   2.18318244  *  -0.00020794  *
#     13       H          2.65663839  *  -0.86521179  *   0.01172463  *
#
#                              CARTESIAN COORDINATES
#
#    1    C       -1.869553739     0.034913355    -0.005069952
#    2    C       -1.202477835    -1.188152187    -0.003887217
#    3    C        0.190652446    -1.233655962     0.001293547
#    4    C        0.887468072    -0.024506173     0.006582276
#    5    C        0.241740351     1.216951004     0.005792277
#    6    C       -1.147478979     1.231552354     0.000518745
#    7    O        2.245392944     0.031886805     0.011825740
#    8    H       -2.956008356     0.062141593    -0.009374329
#    9    H       -1.772149963    -2.116634067    -0.008051673
#   10    H        0.716281240    -2.181647722     0.002121986
#   11    H        0.827854422     2.131359282     0.010049681
#   12    H       -1.679014401     2.183182443    -0.000207937
#   13    H        2.656638386    -0.865211787     0.011724631
#
#
#            Empirical Formula: C6 H6 O  =    13 atoms
#
#
#
#       MOLECULAR POINT GROUP   :   Cs
#
#
#                   EIGENVALUES
#  -30.98447 -30.01318 -26.07794 -25.37246 -21.59313 -20.90730 -18.49047 -16.95734
#  -15.81710 -14.85214 -14.54913 -14.51815 -13.83515 -12.51429 -12.47440 -11.96639
#  -10.08036  -9.23565   0.03523   0.27630   2.40070   2.45093   4.13841   4.21492
#    4.78778   4.91580   5.10543   5.46527   5.67245   5.76268   5.96921   6.09423
#    6.21241   6.32207
#
#
#               NET ATOMIC CHARGES AND DIPOLE CONTRIBUTIONS
#
#   ATOM NO.   TYPE          CHARGE      No. of ELECS.   s-Pop       p-Pop
#     1          C          -0.226376        4.2264     1.07734     3.14904
#     2          C          -0.067285        4.0673     1.08411     2.98318
#     3          C          -0.313144        4.3131     1.07653     3.23661
#     4          C           0.294647        3.7054     1.08047     2.62488
#     5          C          -0.249223        4.2492     1.07638     3.17284
#     6          C          -0.076318        4.0763     1.08569     2.99063
#     7          O          -0.475399        6.4754     1.83799     4.63740
#     8          H           0.154068        0.8459     0.84593
#     9          H           0.147731        0.8523     0.85227
#    10          H           0.159496        0.8405     0.84050
#    11          H           0.175003        0.8250     0.82500
#    12          H           0.149934        0.8501     0.85007
#    13          H           0.326865        0.6731     0.67314
#  DIPOLE           X         Y         Z       TOTAL
#  POINT-CHG.    -0.844    -0.936    -0.004     1.260
#  HYBRID         0.547    -0.337     0.002     0.643
#  SUM           -0.297    -1.273    -0.002     1.308
#
#
#           ATOMIC ORBITAL ELECTRON POPULATIONS
#
#      Atom    s        px        py        pz
#     1  C   1.07734   1.08452   0.98818   1.07634
#     2  C   1.08411   0.99415   1.05073   0.93830
#     3  C   1.07653   1.03004   1.05860   1.14797
#     4  C   1.08047   0.76441   0.96839   0.89209
#     5  C   1.07638   1.01549   1.05637   1.10098
#     6  C   1.08569   0.99600   1.05392   0.94071
#     7  O   1.83799   1.29144   1.44236   1.90360
#     8  H   0.84593
#     9  H   0.85227
#    10  H   0.84050
#    11  H   0.82500
#    12  H   0.85007
#    13  H   0.67314
#
#  **********************
#  *                    *
#  * JOB ENDED NORMALLY *
#  *                    *
#  **********************
#
#
#
#  TOTAL JOB TIME:             0.10 SECONDS
#
#  == MOPAC DONE ==

# %% [markdown]
# # arcファイルの読み取り

# %%
with open('phenol.arc', mode='r') as f:
    lines = f.readlines()
    for line in lines:
        print(line, end='')
# Out:
#                      SUMMARY OF  PM7 CALCULATION
#
#                                                        MOPAC v22.0.4 MacOS
#                                                        Sat Sep 17 21:36:16 2022
#
#            Empirical Formula: C6 H6 O  =    13 atoms
#
#  PM7 EF
#  c1ccc(cc1)O
#  InChI=1S/C6H6O/c7-6-4-2-1-3-5-6/h1-5,7H
#
#
#      GEOMETRY OPTIMISED USING EIGENVECTOR FOLLOWING (EF).
#      SCF FIELD WAS ACHIEVED
#
#           HEAT OF FORMATION       =        -22.15781 KCAL/MOL =     -92.70830 KJ/MOL
#           GRADIENT NORM           =          0.99656          =       0.27640 PER ATOM
#           DIPOLE                  =          1.30764 DEBYE   POINT GROUP:  Cs
#           NO. OF FILLED LEVELS    =         18
#           IONIZATION POTENTIAL    =          9.235653 EV
#           HOMO LUMO ENERGIES (EV) =         -9.236  0.035
#           MOLECULAR WEIGHT        =         94.1128
#           COSMO AREA              =        129.57 SQUARE ANGSTROMS
#           COSMO VOLUME            =        119.27 CUBIC ANGSTROMS
#
#           MOLECULAR DIMENSIONS (Angstroms)
#
#             Atom       Atom       Distance
#             H    13    H     8     5.68878
#             H    11    H     9     4.61502
#             C     1    H    10     0.00066
#           SCF CALCULATIONS        =         19
#           WALL-CLOCK TIME         =      0.102 SECONDS
#           COMPUTATION TIME        =      0.641 SECONDS
#
#
#           FINAL GEOMETRY OBTAINED
#  PM7 EF
#  c1ccc(cc1)O
#  InChI=1S/C6H6O/c7-6-4-2-1-3-5-6/h1-5,7H
#   C    -1.86955374 +1   0.03491335 +1  -0.00506995 +1
#   C    -1.20247783 +1  -1.18815219 +1  -0.00388722 +1
#   C     0.19065245 +1  -1.23365596 +1   0.00129355 +1
#   C     0.88746807 +1  -0.02450617 +1   0.00658228 +1
#   C     0.24174035 +1   1.21695100 +1   0.00579228 +1
#   C    -1.14747898 +1   1.23155235 +1   0.00051874 +1
#   O     2.24539294 +1   0.03188680 +1   0.01182574 +1
#   H    -2.95600836 +1   0.06214159 +1  -0.00937433 +1
#   H    -1.77214996 +1  -2.11663407 +1  -0.00805167 +1
#   H     0.71628124 +1  -2.18164772 +1   0.00212199 +1
#   H     0.82785442 +1   2.13135928 +1   0.01004968 +1
#   H    -1.67901440 +1   2.18318244 +1  -0.00020794 +1
#   H     2.65663839 +1  -0.86521179 +1   0.01172463 +1

# %% [markdown]
# それぞれの意味
#
# HEAT OF FORMATION       =        -22.15781 KCAL/MOL =     -92.70830 KJ/MOL
# GRADIENT NORM           =          0.99656          =       0.27640 PER ATOM
# DIPOLE                  =          1.30764 DEBYE   POINT GROUP:  Cs
# NO. OF FILLED LEVELS    =         18
# IONIZATION POTENTIAL    =          9.235653 EV
# HOMO LUMO ENERGIES (EV) =         -9.236  0.035
# MOLECULAR WEIGHT        =         94.1128
# COSMO AREA              =        129.57 SQUARE ANGSTROMS
# COSMO VOLUME            =        119.27 CUBIC ANGSTROMS

# %% [markdown]
# # 自動で読み取って、pandasのデータフレームに入れるやり方
